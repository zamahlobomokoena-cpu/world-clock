# %% [markdown]
# <a href="https://colab.research.google.com/github/zamahlobomokoena-cpu/world-clock/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 1: Processing the First Order

# Store customer details
customer_name = "Sarah"
drink_ordered = "Cappuccino"
order_price = 45.00

# Display a summary of the order
print("--- Order Summary ---")
print(f"Customer: {customer_name}")
print(f"Drink: {drink_ordered}")
print(f"Price: R{order_price:.2f}")
# Out:
# --- Order Summary ---
# Customer: Sarah
# Drink: Cappuccino
# Price: R45.00
